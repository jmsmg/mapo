# %%
import pandas as pd
import folium

# %%
m = folium.Map(
    location=[37.56619800217754, 126.90164250057964],
    zoom_start=[14]
)

tooltip1 = 'Click'

folium.Marker(
    [37.581888972371935, 126.88949066574179],
    popup = '집'
).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=%3C%21DOCTYPE%20html%3E%0A%3Chead%3E%20%20%20%20%0A%20%20%20%20%3Cmeta%20http-equiv%3D%22content-type%22%20content%3D%22text/html%3B%20charset%3DUTF-8%22%20/%3E%0A%20%20%20%20%3Cscript%3EL_PREFER_CANVAS%20%3D%20false%3B%20L_NO_TOUCH%20%3D%20false%3B%20L_DISABLE_3D%20%3D%20false%3B%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//cdn.jsdelivr.net/npm/leaflet%401.2.0/dist/leaflet.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//ajax.googleapis.com/ajax/libs/jquery/1.11.1/jquery.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%20src%3D%22https%3A//maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js%22%3E%3C/script%3E%0A%20%20%20%20%3Cscript%2
# ...

# %%
df = pd.read_csv('서울시 지정·인증업소 현황.csv', encoding='euc-kr')
df.isnull().sum()
# Out:
# 식품인증업소 관리 일련번호      0
# 업소번호               58
# 업소 명                0
# 자치구 코드              0
# 자치구 명               0
# 업종 코드               0
# 업종 명                0
# 업태 코드              15
# 업태 명               15
# 업주 명               57
# 식품인증구분              0
# 식품인증 구분명            0
# 인증일자                0
# 사용여부                0
# 지도표시여부              0
# 식품인증업소 등급         139
# 지도 Y좌표              0
# 지도 X좌표              0
# 전화번호               78
# 도로명상세주소            49
# 도로명주소코드            58
# 도로명주소               0
# 허가번호               57
# 최초작성일자             62
# 최종수정일자             62
# 업소인증메뉴            399
# 교부번호               62
# 인증여부               57
# dtype: int64

# %%
df_1 = df[['업소 명', '업태 명', '지도 Y좌표', '지도 Y좌표','도로명상세주소']]
df_1
# Out:
#                    업소 명       업태 명     지도 Y좌표     지도 Y좌표  \
# 0              포탈라 (마포)  기타(일반음식점)  37.557139  37.557139
# 1               마포나루1호점        NaN  37.541274  37.541274
# 2                 월드아구찜        NaN  37.565423  37.565423
# 3          크리스피프레시 (합정)        경양식  37.551144  37.551144
# 4               키다리 아저씨         까페  37.558440  37.558440
# 5                 이룸웨딩홀        뷔페식  37.542070  37.542070
# 6                   펠앤콜         까페  37.548169  37.548169
# 7             연우김밥 (성산)         분식  37.558552  37.558552
# 8               포인트프레드릭  기타(일반음식점)  37.553705  37.553705
# 9                  셰발레리        경양식  37.552064  37.552064
# 10                언플러그드         까페  37.555489  37.555489
# 11                어반도투리         한식  37.544738  37.544738
# 12         어게인리프레쉬 (연남)        경양식  37.558931  37.558931
# 13     내여자를부탁해 (메세나폴리스)        경양식  37.549259  37.549259
# 14                  홍쉐프        경양식  37.555717  37.555717
# ...

# %%
del df[['식품인증업소 등급']]
# Out:
#      식품인증업소 등급
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN
# 5          NaN
# 6          NaN
# 7          NaN
# 8          NaN
# 9          NaN
# 10         NaN
# 11         NaN
# 12         NaN
# 13         NaN
# 14         NaN
# 15         NaN
# 16         NaN
# 17         NaN
# 18         NaN
# 19         NaN
# 20         NaN
# 21         NaN
# 22         NaN
# 23         NaN
# 24         NaN
# 25         NaN
# 26         NaN
# 27         NaN
# 28         NaN
# 29         NaN
# ..         ...
# 474        3.0
# 475        3.0
# 476        3.0
# 477        3.0
# 478        3.0
# 479        2.0
# 480        3.0
# 481        3.0
# 482        3.0
# 483        2.0
# 484        3.0
# 485        2.0
# 486        3.0
# 487        3.0
# 488        3.0
# 489        3.0
# 490        3.0
# 491        3.0
# 492        3.0
# 493        3.0
# 494        3.0
# 495        3.0
# 496        3.0
# 497        3.0
# 498        2.0
# 499        3.0
# ...
